# %%
import pandas as pd
import numpy as np
import json
import plotly.express as px
import seaborn as sns
import plotly.graph_objects as go
df = pd.read_json('PDB_profiles_votes.json')

# %%
sample = df.sample(1000, random_state=123).reset_index(drop=True).set_index('name')
sample
# Out:
#                                                                  info  \
# name
# Heraclitus          {'cat': 'Philosophy', 'sub_cat': 'Western Phil...
# Scott               {'cat': 'Movies', 'sub_cat': 'Lemonade Mouth (...
# T.D. Jakes          {'cat': 'Religion', 'sub_cat': 'Classical Refo...
# Don Diego Tenorio   {'cat': 'Theatre', 'sub_cat': 'Don Juan Tenori...
# Kendall Roy         {'cat': 'Television', 'sub_cat': 'Succession (...
# ...                                                               ...
# Karl Lagerfeld      {'cat': 'The Arts', 'sub_cat': 'Fashion Design...
# Ellie Thumann       {'cat': 'Internet', 'sub_cat': 'General Vlogge...
# Miss Ursula Gatsby  {'cat': 'Television', 'sub_cat': 'Fawlty Tower...
# Sorting Hat         {'cat': 'Movies', 'sub_cat': 'Harry Potter / W...
# Fulgore             {'cat': 'Gaming', 'sub_cat': 'Killer Instinct'...
#
#                                                            mbti_votes  \
# name
# Heraclitus          [{'myValue': 'INTJ', 'personality_system_id': ...
# Scott               [{'myValue': 'ESFP', 'personality_system_id': ...
# T.D. Jakes          [{'myValue': 'ENFJ', 'personality_system_id': ...
# Don Diego Tenorio   [{'myValue': 'ISTJ', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'ISFJ', 'personality_system_id': ...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'ENTP', 'personality_system_id': ...
# Ellie Thumann       [{'myValue': 'ESFJ', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'ENTP', 'personality_system_id': ...
# Fulgore             [{'myValue': 'ISTJ', 'personality_system_id': ...
#
#                                                           ngram_votes  \
# name
# Heraclitus          [{'myValue': '5w4', 'personality_system_id': 2...
# Scott               [{'myValue': '3w2', 'personality_system_id': 2...
# T.D. Jakes          [{'myValue': '1w2', 'personality_system_id': 2...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': '6w7', 'personality_system_id': 2...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': '4w3', 'personality_system_id': 2...
# Ellie Thumann       [{'myValue': '2w3', 'personality_system_id': 2...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': '3w4', 'personality_system_id': 2...
# Fulgore             [{'myValue': '8w9', 'personality_system_id': 2...
#
#                                                       socionics_votes  \
# name
# Heraclitus          [{'myValue': 'ILI', 'personality_system_id': 3...
# Scott               [{'myValue': 'ESE', 'personality_system_id': 3...
# T.D. Jakes          [{'myValue': 'XXXX', 'personality_system_id': ...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'LIE', 'personality_system_id': 3...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'EIE', 'personality_system_id': 3...
# Ellie Thumann       [{'myValue': 'ESE', 'personality_system_id': 3...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'EII', 'personality_system_id': 3...
# Fulgore             [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                                      alignement_votes  \
# name
# Heraclitus          [{'myValue': 'True Neutral', 'personality_syst...
# Scott               [{'myValue': 'XXXX', 'personality_system_id': ...
# T.D. Jakes          [{'myValue': 'XXXX', 'personality_system_id': ...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'Chaotic Neutral', 'personality_s...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'XXXX', 'personality_system_id': ...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'True Neutral', 'personality_syst...
# Fulgore             [{'myValue': 'Neutral Evil', 'personality_syst...
#
#                                                  instintual_var_votes  \
# name
# Heraclitus          [{'myValue': 'sp/sx', 'personality_system_id':...
# Scott               [{'myValue': 'sx/so', 'personality_system_id':...
# T.D. Jakes          [{'myValue': 'so/sp', 'personality_system_id':...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'so/sp', 'personality_system_id':...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'sp/sx', 'personality_system_id':...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'sp/sx', 'personality_system_id':...
# Fulgore             [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                                         tritype_votes  \
# name
# Heraclitus          [{'myValue': '514', 'personality_system_id': 6...
# Scott               [{'myValue': '369', 'personality_system_id': 6...
# T.D. Jakes          [{'myValue': '458', 'personality_system_id': 6...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': '639', 'personality_system_id': 6...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': '478', 'personality_system_id': 6...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': '395', 'personality_system_id': 6...
# Fulgore             [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                                     temperament_votes  \
# name
# Heraclitus          [{'myValue': 'Melancholic [Dominant]', 'person...
# Scott               [{'myValue': 'XXXX', 'personality_system_id': ...
# T.D. Jakes          [{'myValue': 'Sanguine-Choleric', 'personality...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'Melancholic [Dominant]', 'person...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'Melancholic [Dominant]', 'person...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'Sanguine-Choleric', 'personality...
# Fulgore             [{'myValue': 'Choleric [Dominant]', 'personali...
#
#                                               attitudnal_psyque_votes  \
# name
# Heraclitus          [{'myValue': 'LVEF', 'personality_system_id': ...
# Scott               [{'myValue': 'FEVL', 'personality_system_id': ...
# T.D. Jakes          [{'myValue': 'XXXX', 'personality_system_id': ...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'FLVE', 'personality_system_id': ...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'VELF', 'personality_system_id': ...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'XXXX', 'personality_system_id': ...
# Fulgore             [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                                            big5_votes
# name
# Heraclitus          [{'myValue': 'RLOEI', 'personality_system_id':...
# Scott               [{'myValue': 'XXXX', 'personality_system_id': ...
# T.D. Jakes          [{'myValue': 'SCOAI', 'personality_system_id':...
# Don Diego Tenorio   [{'myValue': 'XXXX', 'personality_system_id': ...
# Kendall Roy         [{'myValue': 'RLOEN', 'personality_system_id':...
# ...                                                               ...
# Karl Lagerfeld      [{'myValue': 'SCOEI', 'personality_system_id':...
# Ellie Thumann       [{'myValue': 'XXXX', 'personality_system_id': ...
# Miss Ursula Gatsby  [{'myValue': 'XXXX', 'personality_system_id': ...
# Sorting Hat         [{'myValue': 'XXXX', 'personality_system_id': ...
# Fulgore             [{'myValue': 'RCOEN', 'personality_system_id':...
#
# [1000 rows x 10 columns]

# %%
i[1]['info']

df_row = pd.DataFrame([i[1]['info']], index=[i[0]])
# Out:
# {'cat': 'Television',
#  'sub_cat': 'Succession (2018)',
#  'description': "''You’ve won. Because you’re corrupt and so is the world.''",
#  'is_fictional': True}

# %%
for i in sample.iloc[:5].iterrows():
    print(pd.DataFrame([i[1]['info']], index=[i[0]]))
# Out:
#                    cat             sub_cat  \
# Heraclitus  Philosophy  Western Philosophy
#
#                                                   description  is_fictional
# Heraclitus  Heraclitus of Ephesus was a pre-Socratic Greek...         False
#           cat                sub_cat description  is_fictional
# Scott  Movies  Lemonade Mouth (2011)                      True
#                  cat           sub_cat  \
# T.D. Jakes  Religion  Classical Reform
#
#                                                   description  is_fictional
# T.D. Jakes  Thomas Dexter Jakes Sr. (born June 9, 1957), k...         False
#                        cat           sub_cat description  is_fictional
# Don Diego Tenorio  Theatre  Don Juan Tenorio                      True
#                     cat            sub_cat  \
# Kendall Roy  Television  Succession (2018)
#
#                                                    description  is_fictional
# Kendall Roy  ''You’ve won. Because you’re corrupt and so is...          True

# %%
[i[1]['info']], index=[i[0]]

# %%
info_df = pd.DataFrame()
cat_dict = {}
for i in sample.iterrows():
    df_row = pd.DataFrame([i[1]['info']], index=[i[0]])
    #cat_dict[] = (i['cat'])
    info_df = pd.concat([info_df,df_row])

# %%
info_df
# Out:
#                            cat                               sub_cat  \
# Heraclitus          Philosophy                    Western Philosophy
# Scott                   Movies                 Lemonade Mouth (2011)
# T.D. Jakes            Religion                      Classical Reform
# Don Diego Tenorio      Theatre                      Don Juan Tenorio
# Kendall Roy         Television                     Succession (2018)
# ...                        ...                                   ...
# Karl Lagerfeld        The Arts                     Fashion Designers
# Ellie Thumann         Internet                      General Vloggers
# Miss Ursula Gatsby  Television                         Fawlty Towers
# Sorting Hat             Movies  Harry Potter / Wizarding World Films
# Fulgore                 Gaming                       Killer Instinct
#
#                                                           description  \
# Heraclitus          Heraclitus of Ephesus was a pre-Socratic Greek...
# Scott
# T.D. Jakes          Thomas Dexter Jakes Sr. (born June 9, 1957), k...
# Don Diego Tenorio
# Kendall Roy         ''You’ve won. Because you’re corrupt and so is...
# ...                                                               ...
# Karl Lagerfeld      Karl Otto Lagerfeld (10 September 1933 – 19 Fe...
# Ellie Thumann
# Miss Ursula Gatsby
# Sorting Hat
# Fulgore             Fulgore Mk.III is the latest and greatest of U...
#
#                     is_fictional
# Heraclitus                 False
# Scott                       True
# T.D. Jakes                 False
# Don Diego Tenorio           True
# Kendall Roy                 True
# ...                          ...
# Karl Lagerfeld             False
# Ellie Thumann              False
# Miss Ursula Gatsby          True
# Sorting Hat                 True
# Fulgore                     True
#
# [1000 rows x 4 columns]

# %%
info_df['is_fictional'].value_counts()
# Out:
# is_fictional
# True     795
# False    205
# Name: count, dtype: int64

# %%
info_df['cat'].value_counts()/len(info_df)
# Out:
# cat
# Television            0.184
# Gaming                0.151
# Anime & Manga         0.147
# Movies                0.123
# Cartoons              0.060
# Literature            0.053
# Musician              0.047
# Pop Culture           0.039
# Internet              0.025
# The Arts              0.021
# Sports                0.019
# Historical            0.017
# Superheroes           0.016
# Political             0.012
# Traits                0.012
# Web Comics            0.009
# Theatre               0.009
# Science               0.008
# Kpop                  0.007
# Theories              0.006
# Religion              0.006
# Culture               0.006
# Plots & Archetypes    0.004
# Nature                0.004
# Music                 0.004
# Comics                0.003
# Concepts              0.002
# Noteworthy            0.002
# Your Experience       0.002
# Philosophy            0.002
# Name: count, dtype: float64

# %%
pd.merge(info_df, sample, on = sample.index)
# Out:
#                    key_0         cat                               sub_cat  \
# 0             Heraclitus  Philosophy                    Western Philosophy
# 1                  Scott      Movies                 Lemonade Mouth (2011)
# 2             T.D. Jakes    Religion                      Classical Reform
# 3      Don Diego Tenorio     Theatre                      Don Juan Tenorio
# 4            Kendall Roy  Television                     Succession (2018)
# ...                  ...         ...                                   ...
# 999       Karl Lagerfeld    The Arts                     Fashion Designers
# 1000       Ellie Thumann    Internet                      General Vloggers
# 1001  Miss Ursula Gatsby  Television                         Fawlty Towers
# 1002         Sorting Hat      Movies  Harry Potter / Wizarding World Films
# 1003             Fulgore      Gaming                       Killer Instinct
#
#                                             description  is_fictional  \
# 0     Heraclitus of Ephesus was a pre-Socratic Greek...         False
# 1                                                                True
# 2     Thomas Dexter Jakes Sr. (born June 9, 1957), k...         False
# 3                                                                True
# 4     ''You’ve won. Because you’re corrupt and so is...          True
# ...                                                 ...           ...
# 999   Karl Otto Lagerfeld (10 September 1933 – 19 Fe...         False
# 1000                                                            False
# 1001                                                             True
# 1002                                                             True
# 1003  Fulgore Mk.III is the latest and greatest of U...          True
#
#                                                    info  \
# 0     {'cat': 'Philosophy', 'sub_cat': 'Western Phil...
# 1     {'cat': 'Movies', 'sub_cat': 'Lemonade Mouth (...
# 2     {'cat': 'Religion', 'sub_cat': 'Classical Refo...
# 3     {'cat': 'Theatre', 'sub_cat': 'Don Juan Tenori...
# 4     {'cat': 'Television', 'sub_cat': 'Succession (...
# ...                                                 ...
# 999   {'cat': 'The Arts', 'sub_cat': 'Fashion Design...
# 1000  {'cat': 'Internet', 'sub_cat': 'General Vlogge...
# 1001  {'cat': 'Television', 'sub_cat': 'Fawlty Tower...
# 1002  {'cat': 'Movies', 'sub_cat': 'Harry Potter / W...
# 1003  {'cat': 'Gaming', 'sub_cat': 'Killer Instinct'...
#
#                                              mbti_votes  \
# 0     [{'myValue': 'INTJ', 'personality_system_id': ...
# 1     [{'myValue': 'ESFP', 'personality_system_id': ...
# 2     [{'myValue': 'ENFJ', 'personality_system_id': ...
# 3     [{'myValue': 'ISTJ', 'personality_system_id': ...
# 4     [{'myValue': 'ISFJ', 'personality_system_id': ...
# ...                                                 ...
# 999   [{'myValue': 'ENTP', 'personality_system_id': ...
# 1000  [{'myValue': 'ESFJ', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'ENTP', 'personality_system_id': ...
# 1003  [{'myValue': 'ISTJ', 'personality_system_id': ...
#
#                                             ngram_votes  \
# 0     [{'myValue': '5w4', 'personality_system_id': 2...
# 1     [{'myValue': '3w2', 'personality_system_id': 2...
# 2     [{'myValue': '1w2', 'personality_system_id': 2...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': '6w7', 'personality_system_id': 2...
# ...                                                 ...
# 999   [{'myValue': '4w3', 'personality_system_id': 2...
# 1000  [{'myValue': '2w3', 'personality_system_id': 2...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': '3w4', 'personality_system_id': 2...
# 1003  [{'myValue': '8w9', 'personality_system_id': 2...
#
#                                         socionics_votes  \
# 0     [{'myValue': 'ILI', 'personality_system_id': 3...
# 1     [{'myValue': 'ESE', 'personality_system_id': 3...
# 2     [{'myValue': 'XXXX', 'personality_system_id': ...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'LIE', 'personality_system_id': 3...
# ...                                                 ...
# 999   [{'myValue': 'EIE', 'personality_system_id': 3...
# 1000  [{'myValue': 'ESE', 'personality_system_id': 3...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'EII', 'personality_system_id': 3...
# 1003  [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                        alignement_votes  \
# 0     [{'myValue': 'True Neutral', 'personality_syst...
# 1     [{'myValue': 'XXXX', 'personality_system_id': ...
# 2     [{'myValue': 'XXXX', 'personality_system_id': ...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'Chaotic Neutral', 'personality_s...
# ...                                                 ...
# 999   [{'myValue': 'XXXX', 'personality_system_id': ...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'True Neutral', 'personality_syst...
# 1003  [{'myValue': 'Neutral Evil', 'personality_syst...
#
#                                    instintual_var_votes  \
# 0     [{'myValue': 'sp/sx', 'personality_system_id':...
# 1     [{'myValue': 'sx/so', 'personality_system_id':...
# 2     [{'myValue': 'so/sp', 'personality_system_id':...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'so/sp', 'personality_system_id':...
# ...                                                 ...
# 999   [{'myValue': 'sp/sx', 'personality_system_id':...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'sp/sx', 'personality_system_id':...
# 1003  [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                           tritype_votes  \
# 0     [{'myValue': '514', 'personality_system_id': 6...
# 1     [{'myValue': '369', 'personality_system_id': 6...
# 2     [{'myValue': '458', 'personality_system_id': 6...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': '639', 'personality_system_id': 6...
# ...                                                 ...
# 999   [{'myValue': '478', 'personality_system_id': 6...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': '395', 'personality_system_id': 6...
# 1003  [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                       temperament_votes  \
# 0     [{'myValue': 'Melancholic [Dominant]', 'person...
# 1     [{'myValue': 'XXXX', 'personality_system_id': ...
# 2     [{'myValue': 'Sanguine-Choleric', 'personality...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'Melancholic [Dominant]', 'person...
# ...                                                 ...
# 999   [{'myValue': 'Melancholic [Dominant]', 'person...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'Sanguine-Choleric', 'personality...
# 1003  [{'myValue': 'Choleric [Dominant]', 'personali...
#
#                                 attitudnal_psyque_votes  \
# 0     [{'myValue': 'LVEF', 'personality_system_id': ...
# 1     [{'myValue': 'FEVL', 'personality_system_id': ...
# 2     [{'myValue': 'XXXX', 'personality_system_id': ...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'FLVE', 'personality_system_id': ...
# ...                                                 ...
# 999   [{'myValue': 'VELF', 'personality_system_id': ...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1003  [{'myValue': 'XXXX', 'personality_system_id': ...
#
#                                              big5_votes
# 0     [{'myValue': 'RLOEI', 'personality_system_id':...
# 1     [{'myValue': 'XXXX', 'personality_system_id': ...
# 2     [{'myValue': 'SCOAI', 'personality_system_id':...
# 3     [{'myValue': 'XXXX', 'personality_system_id': ...
# 4     [{'myValue': 'RLOEN', 'personality_system_id':...
# ...                                                 ...
# 999   [{'myValue': 'SCOEI', 'personality_system_id':...
# 1000  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1001  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1002  [{'myValue': 'XXXX', 'personality_system_id': ...
# 1003  [{'myValue': 'RCOEN', 'personality_system_id':...
#
# [1004 rows x 15 columns]

# %%
# Initialize an empty dictionary to store dataframes for each type of count
all_data_df = {}

# Assuming `sample` is a DataFrame with columns for each type of vote data
for col in sample.columns[1:]:
    vote_counts = {}
    for row, votes in enumerate(sample[col]):
        character = sample.index[row]
        vote_counts[character] = {vote['myValue']: vote['theCount'] for vote in votes}
    
    # Convert vote_counts to a DataFrame
    vote_counts_df = pd.DataFrame(vote_counts).transpose()
    
    # Store the DataFrame in the all_data_df dictionary
    all_data_df[col] = vote_counts_df

# Access each DataFrame by the type of count
mbti_counts_df = all_data_df['mbti_votes'].drop(columns = 'XXXX')
enneagram_counts_df = all_data_df['ngram_votes'].drop(columns = 'XXXX')
socionics_counts_df = all_data_df['socionics_votes'].drop(columns = 'XXXX')
alignement_counts_df = all_data_df['alignement_votes'].drop(columns = 'XXXX')
instinctual_variant_counts_df = all_data_df['instintual_var_votes'].drop(columns = 'XXXX')
tritype_counts_df = all_data_df['tritype_votes'].drop(columns = 'XXXX')
temperaments_counts_df = all_data_df['temperament_votes'].drop(columns = 'XXXX')
attitudnal_psyque_counts_df = all_data_df['attitudnal_psyque_votes'].drop(columns = 'XXXX')
big5_counts_df = all_data_df['big5_votes'].drop(columns = 'XXXX')

# If you want to combine all DataFrames into one, you can use the following:
combined_df = pd.concat(all_data_df, axis=1)

# %%
alignement_counts_df
# Out:
#                     True Neutral  Chaotic Neutral  Lawful Neutral  \
# Heraclitus                   4.0              NaN             NaN
# Scott                        NaN              NaN             NaN
# T.D. Jakes                   NaN              NaN             NaN
# Don Diego Tenorio            NaN              NaN             NaN
# Kendall Roy                  5.0              6.0             6.0
# ...                          ...              ...             ...
# Karl Lagerfeld               NaN              NaN             NaN
# Ellie Thumann                NaN              NaN             NaN
# Miss Ursula Gatsby           NaN              NaN             NaN
# Sorting Hat                  6.0              NaN             NaN
# Fulgore                      NaN              NaN             NaN
#
#                     Lawful Evil  Chaotic Good  Neutral Evil  Lawful Good  \
# Heraclitus                  NaN           NaN           NaN          NaN
# Scott                       NaN           NaN           NaN          NaN
# T.D. Jakes                  NaN           NaN           NaN          NaN
# Don Diego Tenorio           NaN           NaN           NaN          NaN
# Kendall Roy                 3.0           2.0           1.0          NaN
# ...                         ...           ...           ...          ...
# Karl Lagerfeld              NaN           NaN           NaN          NaN
# Ellie Thumann               NaN           NaN           NaN          NaN
# Miss Ursula Gatsby          NaN           NaN           NaN          NaN
# Sorting Hat                 NaN           NaN           NaN          NaN
# Fulgore                     NaN           NaN           1.0          NaN
#
#                     Chaotic Evil  Neutral Good
# Heraclitus                   NaN           NaN
# Scott                        NaN           NaN
# T.D. Jakes                   NaN           NaN
# Don Diego Tenorio            NaN           NaN
# Kendall Roy                  NaN           NaN
# ...                          ...           ...
# Karl Lagerfeld               NaN           NaN
# Ellie Thumann                NaN           NaN
# Miss Ursula Gatsby           NaN           NaN
# Sorting Hat                  NaN           NaN
# Fulgore                      NaN           NaN
#
# [998 rows x 9 columns]

# %%
def get_most_likely_mbti(df):
    
    mbti_df = df.copy()
    mbti_df['prob_E'] = None
    mbti_df['prob_N'] = None
    mbti_df['prob_T'] = None
    mbti_df['prob_P'] = None
    mbti_df['prob_MBTI'] = None
    for row in range(len(mbti_df)):
        df1 = mbti_df.iloc[row].to_frame().rename(columns={mbti_df.iloc[row].to_frame().columns[0]: 'votes'})
        df1['E_I'] = df1.index.str[0]
        if df1['votes'].sum() <= 10:
            continue
        # Count occurrences of E and I
        prob_E = df1[df1['E_I'] == 'E']['votes'].sum()/df1['votes'].sum()
        prob_I = df1[df1['E_I'] == 'I']['votes'].sum()/df1['votes'].sum()
        mbti_df['prob_E'].iloc[row] = prob_E

        df1['N_S'] = df1.index.str[1]
        # Count occurrences of N and S
        prob_N = df1[df1['N_S'] == 'N']['votes'].sum()/df1['votes'].sum()
        prob_S = df1[df1['N_S'] == 'S']['votes'].sum()/df1['votes'].sum()
        mbti_df['prob_N'].iloc[row] = prob_N

        df1['T_F'] = df1.index.str[2]
        # Count occurrences of T and F
        prob_T = df1[df1['T_F'] == 'T']['votes'].sum()/df1['votes'].sum()
        prob_F = df1[df1['T_F'] == 'F']['votes'].sum()/df1['votes'].sum()
        mbti_df['prob_T'].iloc[row] = prob_T

        df1['P_J'] = df1.index.str[3]
        # Count occurrences of P and J
        prob_P = df1[df1['P_J'] == 'P']['votes'].sum()/df1['votes'].sum()
        prob_J = df1[df1['P_J'] == 'J']['votes'].sum()/df1['votes'].sum()
        mbti_df['prob_P'].iloc[row] = prob_P

        personality = ''
        if prob_E >= 0.5:
            personality+='E'
        else:
            personality+='I'

        if prob_N >= 0.5:
            personality+='N'
        else:
            personality+='S'

        if prob_T >= 0.5:
            personality+='T'
        else:
            personality+='F'

        if prob_P >= 0.5:
            personality+='P'
        else:
            personality+='J'

        mbti_df['prob_MBTI'].iloc[row] = personality

    return mbti_df



def get_most_likely_enneagram(enneagram_df):
    
    new_enneagram_df = enneagram_df.copy()
    new_enneagram_df['prob_1'] = None
    new_enneagram_df['prob_2'] = None
    new_enneagram_df['prob_3'] = None
    new_enneagram_df['prob_4'] = None
    new_enneagram_df['prob_5'] = None
    new_enneagram_df['prob_6'] = None
    new_enneagram_df['prob_7'] = None
    new_enneagram_df['prob_8'] = None
    new_enneagram_df['prob_9'] = None
    new_enneagram_df['prob_Enneagram'] = None
    
    for row in range(len(new_enneagram_df)):
        
        
        df1 = new_enneagram_df.iloc[row].to_frame().rename(columns={new_enneagram_df.iloc[row].to_frame().columns[0]: 'votes'})
        
        if df1['votes'].sum() <= 10:
            continue

        wings = list(df1.index)
        prob_max = []
        for i in range(1, 10):
            votes_for_i = df1.loc[df1.index.str[0].isin([f'{i}']), 'votes'].sum()
            new_enneagram_df[f'prob_{i}'].iloc[row] = votes_for_i / df1['votes'].sum()
            prob_max.append([i,  new_enneagram_df[f'prob_{i}'].iloc[row]])

        most_likely_type = max(prob_max, key=lambda x: x[1])[0]
        most_likely_type_votes = df1.loc[df1.index.str.startswith(f'{most_likely_type}'), 'votes'].to_dict()
        most_likely_enneagram = max(most_likely_type_votes, key=most_likely_type_votes.get)
        new_enneagram_df['prob_Enneagram'].iloc[row] = most_likely_enneagram

    return new_enneagram_df

def get_most_likely_socionics(df):
    # Initialize columns for probabilities and the most likely Socionics type
    socionics_df = df.copy()
    socionics_df['prob_Socionics'] = None
    
    for row in range(len(socionics_df)):
        df1 = socionics_df.iloc[row].to_frame().rename(columns={socionics_df.iloc[row].to_frame().columns[0]: 'votes'})
        #print(row)
        if df1['votes'].sum() <= 10:
            continue
        values = ['E', 'I', 'S', 'L']
        prob_max = []
        for i in values:
            votes_for_i = df1.loc[df1.index.str[0].isin([f'{i}']), 'votes'].sum()
            prob_max.append([i,   votes_for_i / df1['votes'].sum()] )

        most_likely_type = max(prob_max, key=lambda x: x[1])[0]
        most_likely_type_votes = df1.loc[df1.index.str[0].isin([most_likely_type]), 'votes'].to_dict()
        prob_max2 = []
        for j in values:
        
            votes_for_i2 = df1.loc[most_likely_type_votes.keys()].loc[df1.loc[most_likely_type_votes.keys()].index.str[1].isin([f'{j}']), 'votes'].sum()
            #print( prob_max, most_likely_type, votes_for_i2 )
            prob_max2.append([j,   votes_for_i2 / df1.loc[most_likely_type_votes.keys()]['votes'].sum()] )


        most_likely_type2 = max(prob_max2, key=lambda x: x[1])[0]
        most_likely_type_votes2 = df1.loc[most_likely_type_votes.keys()].loc[df1.loc[most_likely_type_votes.keys()].index.str[1].isin([most_likely_type2]), 'votes'].to_dict()
        socionics_df['prob_Socionics'].iloc[row] = max(most_likely_type_votes2, key=most_likely_type_votes2.get)  
    
    return socionics_df

new_socionics_df = get_most_likely_socionics(socionics_counts_df)
new_enneagram_df = get_most_likely_enneagram(enneagram_counts_df)
new_mbti_df = get_most_likely_mbti(df = mbti_counts_df)
# Out:
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:128: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caoco\AppData\Local\Temp\ipykernel_10372\1715489618.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # MBTI analysis

# %%
# Assuming enneagram_counts_df is already defined and contains the data
correlation_matrix = mbti_counts_df.corr()

# Create the heatmap using Plotly
fig = go.Figure(data=go.Heatmap(
    z=correlation_matrix.values,
    x=correlation_matrix.columns,
    y=correlation_matrix.index,
    colorscale='Viridis',  # You can choose other color scales as well
    colorbar=dict(title='Correlation')
))

# Customize the layout for better aesthetics
fig.update_layout(
    title='MBTI Votes Correlation',
    xaxis_title='Variables',
    yaxis_title='Variables',
    template='plotly_white',  # Using a clean white template
    title_x=0.5  # Center the title
)

fig.show()
# Out:
# <div>                            <div id="f0cc3c24-08a2-4cb9-8be2-5b992df4bc32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0cc3c24-08a2-4cb9-8be2-5b992df4bc32")) {                    Plotly.newPlot(                        "f0cc3c24-08a2-4cb9-8be2-5b992df4bc32",                        [{"colorbar":{"title":{"text":"Correlation"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":["INTJ","INTP","INFJ","ESTP","ISTJ","ESFP","ESFJ","ISFP","ENFJ","ISFJ","ENTJ","INFP","ESTJ","ENFP","ENTP","ISTP"],"y":["INTJ","INTP","INFJ","ESTP","ISTJ","ESFP","ESFJ","ISFP","ENFJ","ISFJ","ENTJ","INFP","ESTJ","ENFP","ENTP","ISTP"],"z":[[1.0,-0.040894907971654404,-0.07161338250256906,-0.06209654929629352,0.058034815105781526,-0.07461759841468855,-0.0773503252576569,0.43837115791721926,-0.057290890883124945,-0.08319250535718746,0.0649021801731528,-0.04670921567937911,-0.023377843997623965,-0.06217521438623885,-0.07667656028351016,0.05584050319863184],[-0.040894907971654404,1.0,-0.03815788044378928,-0.06674376415750757,-0.03614843201600107,0.19716994521675688,-
#  is_T  0.273237  0.266220  1.000000  0.251838
#  is_P  0.317266  0.297947  0.251838  1.000000,
#            is_E      is_N      is_T      is_P
#  is_E  1.000000  0.043694  0.048317  0.078242
#  is_N  0.043694  1.000000  0.012699  0.022312
#  is_T  0.048317  0.012699  1.000000 -0.013618
#  is_P  0.078242  0.022312 -0.013618  1.000000)

# %%
df2[['is_E', 'is_N','is_T','is_P']].sum()/len(df2)
# Out:
# is_E    0.478195
# is_N    0.533835
# is_T    0.484211
# is_P    0.547368
# dtype: float64

# %%
import plotly.express as px

# Assuming df2 is already defined and contains the 'prob_MBTI' column
prob_MBTI_counts = (df2['prob_MBTI'].value_counts()/len( df2['prob_MBTI']  ) ).reset_index()
prob_MBTI_counts.columns = ['prob_MBTI', 'count']

# Create the bar plot using Plotly
fig = px.bar(
    prob_MBTI_counts, 
    x='prob_MBTI', 
    y='count', 
    title='Distribution of prob_MBTI Values', 
    labels={'prob_MBTI': 'MBTI Type', 'count': 'Count'},
    color='count',  # Coloring by count for better visualization
    color_continuous_scale=px.colors.sequential.Viridis  # You can choose other color scales as well
)

# Customize the layout for better aesthetics
fig.update_layout(
    title={'x':0.5, 'xanchor': 'center'},  # Center the title
    xaxis_title='MBTI Type',
    yaxis_title='Count',
    template='plotly_white',  # Using a clean white template
    xaxis=dict(
        tickmode='array',
        tickvals=prob_MBTI_counts['prob_MBTI'],
        ticktext=prob_MBTI_counts['prob_MBTI'],
        categoryorder='total descending'  # Sorting by count
    )
)

fig.show()
# Out:
# <div>                            <div id="ba0c1208-5a41-4382-8fc9-6d5cb1e58da9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba0c1208-5a41-4382-8fc9-6d5cb1e58da9")) {                    Plotly.newPlot(                        "ba0c1208-5a41-4382-8fc9-6d5cb1e58da9",                        [{"alignmentgroup":"True","hovertemplate":"MBTI Type=%{x}<br>Count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.08270676691729323,0.07969924812030076,0.07368421052631578,0.07368421052631578,0.07218045112781955,0.061654135338345864,0.061654135338345864,0.061654135338345864,0.06015037593984962,0.06015037593984962,0.058646616541353384,0.05714285714285714,0.05714285714285714,0.04962406015037594,0.04661654135338346,0.04360902255639098],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["ENTP","ENFP","ISFP","INFP","INFJ","ISFJ","ISTJ","INTP","INTJ","ESTP","ESFP","ISTP","ENTJ","ESFJ","ENFJ","ESTJ"],"xaxis":"x","y":[0.08270676691729323,0.07969924812030076,0.07368421052631578,0.07368421052631578,0.07218045112781955,0.061654135338345864,0.061654135338345864,0.061654135338345864,0.06015037593984962,0.06015037593984962,0.058646616541353384,0.05714285714285714,0.05714285714285714,0.04962406015037594,0.04661654135338346,0.04360902255639098],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorsc ...

# %% [markdown]
# # NGRAM Analysis

# %%
# Assuming enneagram_counts_df is already defined and contains the data
correlation_matrix = enneagram_counts_df.corr()

# Create the heatmap using Plotly
fig = go.Figure(data=go.Heatmap(
    z=correlation_matrix.values,
    x=correlation_matrix.columns,
    y=correlation_matrix.index,
    colorscale='Viridis',  # You can choose other color scales as well
    colorbar=dict(title='Correlation')
))

# Customize the layout for better aesthetics
fig.update_layout(
    title='Ngram Votes Correlation',
    xaxis_title='Variables',
    yaxis_title='Variables',
    template='plotly_white',  # Using a clean white template
    title_x=0.5  # Center the title
)

fig.show()
# Out:
# <div>                            <div id="60043fa6-7521-4842-ab8c-54d344b87be4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# %%
# data is a Pandas DataFrame
# Assuming 'traits_df' contains your dataset with features and target variable ('ngram')
df1a= new_enneagram_df.copy()

for i in range(1, 10):
    df1a[f'is_{i}'] = np.where(df1a['prob_Enneagram'].str[0] == f'{i}', True, False)


df2a = df1a.loc[df1a['prob_Enneagram'].dropna().index]

df1a[df1a.columns[-9:]].corr(), df2a[df1a.columns[-9:]].corr()
# Out:
# (          is_1      is_2      is_3      is_4      is_5      is_6      is_7  \
#  is_1  1.000000 -0.039039 -0.039583 -0.044721 -0.047117 -0.052944 -0.052514
#  is_2 -0.039039  1.000000 -0.039039 -0.044106 -0.046469 -0.052216 -0.051791
#  is_3 -0.039583 -0.039039  1.000000 -0.044721 -0.047117 -0.052944 -0.052514
#  is_4 -0.044721 -0.044106 -0.044721  1.000000 -0.053233 -0.059817 -0.059330
#  is_5 -0.047117 -0.046469 -0.047117 -0.053233  1.000000 -0.063021 -0.062508
#  is_6 -0.052944 -0.052216 -0.052944 -0.059817 -0.063021  1.000000 -0.070239
#  is_7 -0.052514 -0.051791 -0.052514 -0.059330 -0.062508 -0.070239  1.000000
#  is_8 -0.045692 -0.045063 -0.045692 -0.051623 -0.054388 -0.061115 -0.060617
#  is_9 -0.049420 -0.048740 -0.049420 -0.055835 -0.058826 -0.066102 -0.065564
#
#            is_8      is_9
#  is_1 -0.045692 -0.049420
#  is_2 -0.045063 -0.048740
#  is_3 -0.045692 -0.049420
#  is_4 -0.051623 -0.055835
#  is_5 -0.054388 -0.058826
#  is_6 -0.061115 -0.066102
#  is_7 -0.060617 -0.065564
#  is_8  1.000000 -0.057047
#  is_9 -0.057047  1.000000  ,
#            is_1      is_2      is_3      is_4      is_5      is_6      is_7  \
#  is_1  1.000000 -0.090245 -0.091566 -0.104174 -0.110148 -0.124964 -0.123854
#  is_2 -0.090245  1.000000 -0.090245 -0.102671 -0.108558 -0.123160 -0.122066
#  is_3 -0.091566 -0.090245  1.000000 -0.104174 -0.110148 -0.124964 -0.123854
#  is_4 -0.104174 -0.102671 -0.104174  1.000000 -0.125314 -0.142171 -0.140907
#  is_5 -0.110148 -0.108558 -0.110148 -0.125314  1.000000 -0.150323 -0.148987
#  is_6 -0.124964 -0.123160 -0.124964 -0.142171 -0.150323  1.000000 -0.169027
#  is_7 -0.123854 -0.122066 -0.123854 -0.140907 -0.148987 -0.169027  1.000000
#  is_8 -0.106586 -0.105048 -0.106586 -0.121262 -0.128215 -0.145462 -0.144169
#  is_9 -0.115953 -0.114280 -0.115953 -0.131919 -0.139484 -0.158246 -0.156840
#
#            is_8      is_9
#  is_1 -0.106586 -0.115953
#  is_2 -0.105048 -0.114280
#  is_3 -0.106586 -0.115953
#  is_4 -0.121262 -0.131919
#  is_5 -0.128215 -0.139484
#  is_6 -0.145462 -0.158246
#  is_7 -0.144169 -0.156840
#  is_8  1.000000 -0.134973
#  is_9 -0.134973  1.000000  )

# %%
( df2a[df1a.columns[-9:]].sum()/len(df2a))#.sort_values(ascending=False)
# Out:
# is_1    0.083885
# is_2    0.081678
# is_3    0.083885
# is_4    0.105960
# is_5    0.116998
# is_6    0.145695
# is_7    0.143488
# is_8    0.110375
# is_9    0.128035
# dtype: float64

# %%
import plotly.express as px

# Assuming df2 is already defined and contains the 'prob_MBTI' column
prob_NGRAM_counts = (df2a['prob_Enneagram'].value_counts()/len( df2a['prob_Enneagram']  )).reset_index()
prob_NGRAM_counts.columns = ['prob_Enneagram', 'count']

# Create the bar plot using Plotly
fig = px.bar(
    prob_NGRAM_counts, 
    x='prob_Enneagram', 
    y='count', 
    title='Distribution of prob_Enneagram Values', 
    labels={'prob_Enneagram': 'Ngram Type', 'count': 'Count'},
    color='count',  # Coloring by count for better visualization
    color_continuous_scale=px.colors.sequential.Viridis  # You can choose other color scales as well
)

# Customize the layout for better aesthetics
fig.update_layout(
    title={'x':0.5, 'xanchor': 'center'},  # Center the title
    xaxis_title='Ngram Type',
    yaxis_title='Count',
    template='plotly_white',  # Using a clean white template
    xaxis=dict(
        tickmode='array',
        tickvals=prob_NGRAM_counts['prob_Enneagram'],
        ticktext=prob_NGRAM_counts['prob_Enneagram'],
        categoryorder='total descending'  # Sorting by count
    )
)

fig.show()
# Out:
# <div>                            <div id="0e53ab84-90a7-46f3-a7e9-7e62f29a21d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e53ab84-90a7-46f3-a7e9-7e62f29a21d6")) {                    Plotly.newPlot(                        "0e53ab84-90a7-46f3-a7e9-7e62f29a21d6",                        [{"alignmentgroup":"True","hovertemplate":"Ngram Type=%{x}<br>Count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.11479028697571744,0.09933774834437085,0.09933774834437085,0.0772626931567329,0.07505518763796909,0.0706401766004415,0.059602649006622516,0.052980132450331126,0.04415011037527594,0.04415011037527594,0.039735099337748346,0.039735099337748346,0.039735099337748346,0.03090507726269316,0.03090507726269316,0.02869757174392936,0.02869757174392936,0.024282560706401765],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["6w7","9w1","7w6","5w4","4w5","8w9","3w2","2w3","1w2","7w8","8w7","5w6","1w9","6w5","4w3","9w8","2w1","3w4"],"xaxis":"x","y":[0.11479028697571744,0.09933774834437085,0.09933774834437085,0.0772626931567329,0.07505518763796909,0.0706401766004415,0.059602649006622516,0.052980132450331126,0.04415011037527594,0.04415011037527594,0.039735099337748346,0.039735099337748346,0.039735099337748346,0.03090507726269316,0.03090507726269316,0.02869757174392936,0.02869757174392936,0.024282560706401765],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2 ...

# %% [markdown]
# # Socionics analysis

# %%
# Assuming enneagram_counts_df is already defined and contains the data
correlation_matrix = socionics_counts_df.corr()

# Create the heatmap using Plotly
fig = go.Figure(data=go.Heatmap(
    z=correlation_matrix.values,
    x=correlation_matrix.columns,
    y=correlation_matrix.index,
    colorscale='Viridis',  # You can choose other color scales as well
    colorbar=dict(title='Correlation')
))

# Customize the layout for better aesthetics
fig.update_layout(
    title='Socionics Votes Correlation',
    xaxis_title='Variables',
    yaxis_title='Variables',
    template='plotly_white',  # Using a clean white template
    title_x=0.5  # Center the title
)

fig.show()
# Out:
# <div>                            <div id="6a6964be-6b7b-4b3b-8017-03a5452a581e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6
# %%
# Assuming new_socionics_df is already defined and contains the 'prob_socionics' column
df1 = new_socionics_df.copy()

# Allocating columns based on the socionics typology positions
df1['is_E1'] = np.where(df1['prob_Socionics'].str[0] == 'E', True, False)
df1['is_I1'] = np.where(df1['prob_Socionics'].str[0] == 'I', True, False)
df1['is_S1'] = np.where(df1['prob_Socionics'].str[0] == 'S', True, False)
df1['is_L1'] = np.where(df1['prob_Socionics'].str[0] == 'L', True, False)

df1['is_E2'] = np.where(df1['prob_Socionics'].str[1] == 'E', True, False)
df1['is_I2'] = np.where(df1['prob_Socionics'].str[1] == 'I', True, False)
df1['is_S2'] = np.where(df1['prob_Socionics'].str[1] == 'S', True, False)
df1['is_L2'] = np.where(df1['prob_Socionics'].str[1] == 'L', True, False)

df1['is_E3'] = np.where(df1['prob_Socionics'].str[2] == 'E', True, False)
df1['is_I3'] = np.where(df1['prob_Socionics'].str[2] == 'I', True, False)

# Print the result
df1
# Out:
#                      ILI  EIE   IEI  ESE   LIE   ESI   SEE  LSE  LSI  LII  \
# Heraclitus          71.0  2.0   2.0  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Scott                NaN  NaN   NaN  1.0   NaN   NaN   NaN  NaN  NaN  NaN
# T.D. Jakes           NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Don Diego Tenorio    NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Kendall Roy          NaN  6.0  10.0  NaN  52.0  12.0  10.0  6.0  NaN  NaN
# ...                  ...  ...   ...  ...   ...   ...   ...  ...  ...  ...
# Karl Lagerfeld       1.0  5.0   2.0  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Ellie Thumann        NaN  NaN   NaN  1.0   NaN   NaN   NaN  NaN  NaN  NaN
# Miss Ursula Gatsby   NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Sorting Hat          NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  NaN  NaN
# Fulgore              NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  NaN  NaN
#
#                     ...  is_E1  is_I1  is_S1  is_L1  is_E2  is_I2  is_S2  \
# Heraclitus          ...  False   True  False  False  False  False  False
# Scott               ...  False  False  False  False  False  False  False
# T.D. Jakes          ...  False  False  False  False  False  False  False
# Don Diego Tenorio   ...  False  False  False  False  False  False  False
# Kendall Roy         ...  False  False  False   True  False   True  False
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# Karl Lagerfeld      ...  False   True  False  False  False  False  False
# Ellie Thumann       ...  False  False  False  False  False  False  False
# Miss Ursula Gatsby  ...  False  False  False  False  False  False  False
# Sorting Hat         ...  False  False  False  False  False  False  False
# Fulgore             ...  False  False  False  False  False  False  False
#
#                     is_L2  is_E3  is_I3
# Heraclitus           True  False   True
# Scott               False  False  False
# T.D. Jakes          False  False  False
# Don Diego Tenorio   False  False  False
# Kendall Roy         False   True  False
# ...                   ...    ...    ...
# Karl Lagerfeld       True   True  False
# Ellie Thumann       False  False  False
# Miss Ursula Gatsby  False  False  False
# Sorting Hat         False  False  False
# Fulgore             False  False  False
#
# [998 rows x 27 columns]
